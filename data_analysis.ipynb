# %%
import pandas as pd

# %%
exerciseResults=pd.read_csv("mp_data-main/mp_data/exerciseResults.csv")
exercises=pd.read_csv("mp_data-main/mp_data/exercises.csv")
journal=pd.read_csv("mp_data-main/mp_data/journal.csv")
moodData=pd.read_csv("mp_data-main/mp_data/moodData.csv")
psychologicalAreas=pd.read_csv("mp_data-main/mp_data/psychologicalAreas.csv")
routineItems=pd.read_csv("mp_data-main/mp_data/routineItems.csv")
scheduledExercises=pd.read_csv("mp_data-main/mp_data/scheduledExercises.csv")
users=pd.read_csv("mp_data-main/mp_data/users.csv")
weeklyExerciseLists=pd.read_csv("mp_data-main/mp_data/weeklyExerciseLists.csv")

# %%
psychologicalAreas.columns
# Out:
# Index(['psychologicalAreas', 'timeStamp', '__key__', '__error__',
#        '__has_error__'],
#       dtype='object')

# %%
psychologicalAreas['__key__'][133]
# Out:
# '{\n  "__key__": {\n    "namespace": "",\n    "app": "e~mentalport-dev",\n    "path": "\\"users\\", \\"c7pOs8yP5KgmNtAHq8OehJf5f8v2\\", \\"psychologicalProfiles\\", \\"NSTL1F7e0yo6WOipzqPZ\\"",\n    "kind": "psychologicalProfiles",\n    "name": "NSTL1F7e0yo6WOipzqPZ",\n    "id": null\n  }\n}'

# %%
users['__key__'][133]
# Out:
# '{\n  "__key__": {\n    "namespace": "",\n    "app": "e~mentalport-dev",\n    "path": "\\"users\\", \\"LCSW49OzfBWh7kRV8m3rWFPSBhb2\\"",\n    "kind": "users",\n    "name": "LCSW49OzfBWh7kRV8m3rWFPSBhb2",\n    "id": null\n  }\n}'

# %%
exercises
# Out:
#      practicability  stress  execution  understandability  \
# 0              True     0.0          0                1.0
# 1             False     0.0          2                0.0
# 2             False     0.0          1                0.0
# 3              True     0.0          0                1.0
# 4              True     0.0          1                1.0
# ..              ...     ...        ...                ...
# 183            True     0.0          0                1.0
# 184            True     0.0          0                0.8
# 185            True     0.0          0                0.8
# 186            True     NaN          0                0.8
# 187            True     0.0          0                1.0
#
#                                                purpose  confidence  \
# 0    Alltagsausrichtung, Energiefresser vermeiden, ...           0
# 1                        Energisierung und Entspannung           0
# 2     Alte Erinnerungen verstehen und Zusammenhänge...           0
# 3    Eigene Entwicklung von Schritten zur Zielerrei...           1
# 4    Eigene Ziele Visualisieren um herauszufinden o...           0
# ..                                                 ...         ...
# 183  Fokus auf die positive Aspekte des Lebens; Dur...           1
# 184  Selbstliebe entwickeln, Lage verbessern, Leben...           1
# 185  Aus vorhandenen Stärken selbst Tätigkeiten ent...           0
# 186  Aus vorhandenen Stärken selbst Tätigkeiten ent...           0
# 187   Emotionen und Gefühle ausdrucken, Gefühl für ...           0
#
#      motivation  discipline  assistance  \
# 0             0           0       False
# 1             0           0       False
# 2             0           0       False
# 3             1           1        True
# 4             1           1        True
# ..          ...         ...         ...
# 183           1           1        True
# 184           1           1        True
# 185           1           1        True
# 186           1           1        True
# 187           0           0       False
#
#                                           tExpenditure  ...  burnout  tRating  \
# 0    {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        0        0
# 1    {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        0        0
# 2    {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        1        2
# 3    {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        0        0
# 4    {\n  "tExpenditure": {\n    "repsMin": "5",\n ...  ...        0        0
# ..                                                 ...  ...      ...      ...
# 183  {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        1        0
# 184  {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        1        1
# 185  {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        0        0
# 186  {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        0        0
# 187  {\n  "tExpenditure": {\n    "repsMin": "1",\n ...  ...        1        1
#
#      daytime  rational                                               info  \
# 0          0      True  {\n  "info": {\n    "instructions": "Schritt 5...
# 1          1     False  {\n  "info": {\n    "instructions": "Um den gr...
# 2          7     False  {\n  "info": {\n    "instructions": "In dieser...
# 3          7      True  {\n  "info": {\n    "instructions": "Nimm dir ...
# 4          1      True  {\n  "info": {\n    "instructions": "Stelle Di...
# ..       ...       ...                                                ...
# 183        7      True  {\n  "info": {\n    "instructions": "Überlege ...
# 184        7      True  {\n  "info": {\n    "instructions": "Deine Erf...
# 185        4      True  {\n  "info": {\n    "instructions": "Führe Dir...
# 186        4      True  {\n  "info": {\n    "instructions": "Führe Dir...
# 187        7      True  {\n  "info": {\n    "instructions": " Schritt ...
#
#      relationship  stressmanagement  \
# 0             NaN               NaN
# 1             NaN               NaN
# 2             NaN               NaN
# 3             NaN               NaN
# 4             NaN               NaN
# ..            ...               ...
# 183           NaN               NaN
# 184           NaN               NaN
# 185           NaN               NaN
# 186           0.0               0.0
# 187           NaN               NaN
#
#                                                __key__ __error__  \
# 0    {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 1    {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 2    {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 3    {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 4    {\n  "__key__": {\n    "namespace": "",\n    "...        []
# ..                                                 ...       ...
# 183  {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 184  {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 185  {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 186  {\n  "__key__": {\n    "namespace": "",\n    "...        []
# 187  {\n  "__key__": {\n    "namespace": "",\n    "...        []
#
#      __has_error__
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 183          False
# 184          False
# 185          False
# 186          False
# 187          False
#
# [188 rows x 29 columns]

# %%
# descriptive statistics
pd.DataFrame.describe(exercises)
# Out:
#            stress   execution  understandability  confidence  motivation  \
# count  151.000000  188.000000         188.000000  188.000000  188.000000
# mean     0.357616    0.638298           0.968085    0.319149    0.489362
# std      0.480893    1.093012           0.128515    0.467392    0.501222
# min      0.000000    0.000000           0.000000    0.000000    0.000000
# 25%      0.000000    0.000000           1.000000    0.000000    0.000000
# 50%      0.000000    0.000000           1.000000    0.000000    0.000000
# 75%      1.000000    1.000000           1.000000    1.000000    1.000000
# max      1.000000    4.000000           1.000000    1.000000    1.000000
#
#        discipline    efficacy     quality   intensity  relationships  \
# count  188.000000  188.000000  188.000000  188.000000     151.000000
# mean     0.414894    0.864362    0.931596    0.393617       0.238411
# std      0.494019    0.538820    0.226500    0.704729       0.427529
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000000    0.500000    0.820000    0.000000       0.000000
# 50%      0.000000    0.500000    0.820000    0.000000       0.000000
# 75%      1.000000    1.000000    1.000000    1.000000       0.000000
# max      1.000000    2.000000    1.360000    2.000000       1.000000
#
#           meaning  sourceVerified  depression     burnout     tRating  \
# count  188.000000      188.000000  188.000000  188.000000  188.000000
# mean     0.478723        0.680851    0.361702    0.388298    0.260638
# std      0.500881        0.467392    0.481776    0.488664    0.586062
# min      0.000000        0.000000    0.000000    0.000000    0.000000
# 25%      0.000000        0.000000    0.000000    0.000000    0.000000
# 50%      0.000000        1.000000    0.000000    0.000000    0.000000
# 75%      1.000000        1.000000    1.000000    1.000000    0.000000
# max      1.000000        1.000000    1.000000    1.000000    2.000000
#
#           daytime  relationship  stressmanagement
# count  188.000000     37.000000         37.000000
# mean     6.441489      0.216216          0.567568
# std      1.502861      0.417342          0.502247
# min      0.000000      0.000000          0.000000
# 25%      7.000000      0.000000          0.000000
# 50%      7.000000      0.000000          1.000000
# 75%      7.000000      0.000000          1.000000
# max      7.000000      1.000000          1.000000
